# %% [markdown]
#
#
#   ANJALI SINGH

# %% [markdown]
# Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset.

# %%
#importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#reading the dataset
df = pd.read_csv('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Mental Health Dataset.csv ')
df.head()
# Out:
#           Timestamp  Age  Gender         Country state self_employed  \
# 0  27-08-2014 11:29   37  Female   United States    IL           NaN
# 1  27-08-2014 11:29   44       M   United States    IN           NaN
# 2  27-08-2014 11:29   32    Male          Canada   NaN           NaN
# 3  27-08-2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4  27-08-2014 11:30   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often          Jun-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely          Jun-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.shape     #size of the dataset
# Out:
# (1259, 27)

# %%
df.index   #return the index array
# Out:
# RangeIndex(start=0, stop=1259, step=1)

# %%
df.values  #return the array containing datavalues
# Out:
# array([['27-08-2014 11:29', 37, 'Female', ..., 'Yes', 'No', nan],
#        ['27-08-2014 11:29', 44, 'M', ..., "Don't know", 'No', nan],
#        ['27-08-2014 11:29', 32, 'Male', ..., 'No', 'No', nan],
#        ...,
#        ['07-11-2015 12:36', 34, 'male', ..., 'No', 'No', nan],
#        ['30-11-2015 21:25', 46, 'f', ..., 'No', 'No', nan],
#        ['01-02-2016 23:04', 25, 'Male', ..., "Don't know", 'No', nan]],
#       dtype=object)

# %%
df.dtypes  #returns the datatype of data values
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# ...

# %%
df.isnull().sum()   #checking total number of null values present int the dataset
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
cols = df.columns #  columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# state                        0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# comments                     0
# dtype: int64

# %%
cols = df.columns #  columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# # NOW DATA IS NOT HAVING ANY NULL VALUES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 24 to 1249
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  86 non-null     object
#  1   Age                        86 non-null     int64
#  2   Gender                     86 non-null     object
#  3   Country                    86 non-null     object
#  4   state                      86 non-null     object
#  5   self_employed              86 non-null     object
#  6   family_history             86 non-null     object
#  7   treatment                  86 non-null     object
#  8   work_interfere             86 non-null     object
#  9   no_employees               86 non-null     object
#  10  remote_work                86 non-null     object
#  11  tech_company               86 non-null     object
#  12  benefits                   86 non-null     object
# ...

# %%
df.shape   #now the updated size of the dataset
# Out:
# (86, 27)

# %% [markdown]
# # REMOVING THE DUPLICATE VALUES

# %%
df = df.drop_duplicates()   # removing the duplicate values from the dataset
df.head()
# Out:
#            Timestamp  Age  Gender        Country state self_employed  \
# 24  27-08-2014 11:36   33    male  United States    CA            No
# 25  27-08-2014 11:37   35    male  United States    TN            No
# 33  27-08-2014 11:39   42    Male  United States    WA            No
# 45  27-08-2014 11:43   38  Female  United States    TX            No
# 49  27-08-2014 11:44   30    male  United States    IL            No
#
#    family_history treatment work_interfere    no_employees  ...  \
# 24            Yes       Yes         Rarely          26-100  ...
# 25            Yes       Yes      Sometimes  More than 1000  ...
# 33            Yes       Yes      Sometimes          26-100  ...
# 45            Yes       Yes      Sometimes          26-100  ...
# 49            Yes       Yes         Rarely          26-100  ...
#
#             leave mental_health_consequence phys_health_consequence  \
# 24     Don't know                        No                      No
# ...

# %%
df.shape   # size of updated dataset
# Out:
# (86, 27)

# %%
df = df.rename(columns={'Timestamp': 'Data and Time'})   # renmaing the columns
df.head(5)
# Out:
#        Data and Time  Age  Gender        Country state self_employed  \
# 24  27-08-2014 11:36   33    male  United States    CA            No
# 25  27-08-2014 11:37   35    male  United States    TN            No
# 33  27-08-2014 11:39   42    Male  United States    WA            No
# 45  27-08-2014 11:43   38  Female  United States    TX            No
# 49  27-08-2014 11:44   30    male  United States    IL            No
#
#    family_history treatment work_interfere    no_employees  ...  \
# 24            Yes       Yes         Rarely          26-100  ...
# 25            Yes       Yes      Sometimes  More than 1000  ...
# 33            Yes       Yes      Sometimes          26-100  ...
# 45            Yes       Yes      Sometimes          26-100  ...
# 49            Yes       Yes         Rarely          26-100  ...
#
#             leave mental_health_consequence phys_health_consequence  \
# 24     Don't know                        No                      No
# ...

# %% [markdown]
# #  Converting categorical data to numeric

# %%
#mapping function

# %%
df.Gender.unique()
# Out:
# array(['male', 'Male', 'Female', 'M', 'F', 'female', 'woman', 'Female ',
#        'm', 'cis-female/femme', 'f', 'Female (cis)', 'Cis Male',
#        'A little about you', 'p'], dtype=object)

# %%
df.Gender[df.Gender == 'male']=1
df.Gender[df.Gender == 'Female']=0
df.Gender[df.Gender == 'M']=1
df.Gender[df.Gender == 'F']=0
df.Gender[df.Gender == 'female']=0
df.Gender[df.Gender == 'woman']=0
df.Gender[df.Gender == 'm']=1
df.Gender[df.Gender == 'cis-female/femme']=2
df.Gender[df.Gender == 'f']=0
df.Gender[df.Gender == 'Female (cis)']= 2
df.Gender[df.Gender == 'Cis Male']=2
df.Gender[df.Gender == 'p']=2
df.Gender[df.Gender == 'A little about you']=2
df.Gender[df.Gender == 'Male']=1
# Out:
# <ipython-input-56-d6003739e558>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Gender[df.Gender == 'male']=1
# <ipython-input-56-d6003739e558>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Gender[df.Gender == 'Female']=0
# <ipython-input-56-d6003739e558>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Gender[df.Gender == 'M']=1
# <ipython-input-56-d6003739e558>:4: SettingWithCopyWarning:
# ...

# %%
df.family_history.unique()
# Out:
# array([1, 0], dtype=object)

# %%
df.fillna(0)
# Out:
#          Data and Time  Age Gender        Country state self_employed  \
# 24    27-08-2014 11:36   33      1  United States    CA            No
# 25    27-08-2014 11:37   35      1  United States    TN            No
# 33    27-08-2014 11:39   42      1  United States    WA            No
# 45    27-08-2014 11:43   38      0  United States    TX            No
# 49    27-08-2014 11:44   30      1  United States    IL            No
# ...                ...  ...    ...            ...   ...           ...
# 1186  06-11-2014 11:24   56      0  United States    OR           Yes
# 1190  03-01-2015 03:38   44      1  United States    OH            No
# 1219  21-02-2015 09:48   38      1  United States    TX            No
# 1221  21-02-2015 10:45   46      1  United States    MD            No
# 1249  22-07-2015 18:57   30      1  United States    CA            No
#
#       family_history  treatment work_interfere    no_employees  ...  \
# ...

# %%
df.family_history.unique()
# Out:
# array([1, 0], dtype=object)

# %%
df.family_history[df.family_history == 'Yes']=1
df.family_history[df.family_history == 'No']=0
# Out:
# <ipython-input-60-7d2d2627fbf7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.family_history[df.family_history == 'Yes']=1
# <ipython-input-60-7d2d2627fbf7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.family_history[df.family_history == 'No']=0

# %%
df.keys()
# Out:
# Index(['Data and Time', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
df
# Out:
#          Data and Time  Age Gender        Country state self_employed  \
# 24    27-08-2014 11:36   33      1  United States    CA            No
# 25    27-08-2014 11:37   35      1  United States    TN            No
# 33    27-08-2014 11:39   42      1  United States    WA            No
# 45    27-08-2014 11:43   38      0  United States    TX            No
# 49    27-08-2014 11:44   30      1  United States    IL            No
# ...                ...  ...    ...            ...   ...           ...
# 1186  06-11-2014 11:24   56      0  United States    OR           Yes
# 1190  03-01-2015 03:38   44      1  United States    OH            No
# 1219  21-02-2015 09:48   38      1  United States    TX            No
# 1221  21-02-2015 10:45   46      1  United States    MD            No
# 1249  22-07-2015 18:57   30      1  United States    CA            No
#
#      family_history treatment work_interfere    no_employees  ...   anonymity  \
# ...

# %%
df.treatment.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.treatment[df.treatment == 'Yes']=1
df.treatment[df.treatment == 'No']=0
# Out:
# <ipython-input-27-02a4a66ba06a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.treatment[df.treatment == 'Yes']=1
# <ipython-input-27-02a4a66ba06a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.treatment[df.treatment == 'No']=0

# %%
df.self_employed.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.self_employed[df.self_employed == 'No']=0
df.self_employed[df.self_employed == 'Yes']=0
# Out:
# <ipython-input-64-a62c57bb4b49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.self_employed[df.self_employed == 'No']=0
# <ipython-input-64-a62c57bb4b49>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.self_employed[df.self_employed == 'Yes']=0

# %%
df.supervisor.unique()
# Out:
# array([1, 2, 0], dtype=object)

# %%
df.supervisor[df.supervisor == 'Yes']=1
df.supervisor[df.supervisor == 'No']=0
df.supervisor[df.supervisor == 'Some of them']=2
# Out:
# <ipython-input-66-b991e61bf363>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.supervisor[df.supervisor == 'Yes']=1
# <ipython-input-66-b991e61bf363>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.supervisor[df.supervisor == 'No']=0
# <ipython-input-66-b991e61bf363>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.supervisor[df.supervisor == 'Some of them']=2

# %%
df.mental_vs_physical.unique()
# Out:
# array(["Don't know", 0, 1], dtype=object)

# %%
df.mental_vs_physical[df.mental_vs_physical== 'Yes'] =1
df.mental_vs_physical[df.mental_vs_physical== 'No'] =0
df.mental_vs_physical[df.mental_vs_physical== 'Dont know']=2
# Out:
# <ipython-input-68-b79d32c2c809>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mental_vs_physical[df.mental_vs_physical== 'Yes'] =1
# <ipython-input-68-b79d32c2c809>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mental_vs_physical[df.mental_vs_physical== 'No'] =0
# <ipython-input-68-b79d32c2c809>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mental_vs_physical[df.mental_vs_physical== 'Dont know']=2

# %% [markdown]
# # Removing uselss columns from the dataset

# %%
df.drop('comments',inplace = True , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-9b099b02f66a> in <module>
# ----> 1 df.drop('comments',inplace = True , axis = 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df
# Out:
#          Data and Time  Age Gender        Country state self_employed  \
# 24    27-08-2014 11:36   33      1  United States    CA             0
# 25    27-08-2014 11:37   35      1  United States    TN             0
# 33    27-08-2014 11:39   42      1  United States    WA             0
# 45    27-08-2014 11:43   38      0  United States    TX             0
# 49    27-08-2014 11:44   30      1  United States    IL             0
# ...                ...  ...    ...            ...   ...           ...
# 1186  06-11-2014 11:24   56      0  United States    OR             0
# 1190  03-01-2015 03:38   44      1  United States    OH             0
# 1219  21-02-2015 09:48   38      1  United States    TX             0
# 1221  21-02-2015 10:45   46      1  United States    MD             0
# 1249  22-07-2015 18:57   30      1  United States    CA             0
#
#      family_history treatment work_interfere    no_employees  ...   anonymity  \
# ...

# %%
df.columns
# Out:
# Index(['Data and Time', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
df.drop(['wellness_program', 'seek_help', 'anonymity','obs_consequence'], axis = 1)
# Out:
#          Data and Time  Age Gender        Country state self_employed  \
# 24    27-08-2014 11:36   33      1  United States    CA             0
# 25    27-08-2014 11:37   35      1  United States    TN             0
# 33    27-08-2014 11:39   42      1  United States    WA             0
# 45    27-08-2014 11:43   38      0  United States    TX             0
# 49    27-08-2014 11:44   30      1  United States    IL             0
# ...                ...  ...    ...            ...   ...           ...
# 1186  06-11-2014 11:24   56      0  United States    OR             0
# 1190  03-01-2015 03:38   44      1  United States    OH             0
# 1219  21-02-2015 09:48   38      1  United States    TX             0
# 1221  21-02-2015 10:45   46      1  United States    MD             0
# 1249  22-07-2015 18:57   30      1  United States    CA             0
#
#      family_history treatment work_interfere    no_employees  ...    benefits  \
# ...

# %%
df.size
# Out:
# 2236

# %% [markdown]
# # Exporting our cleaned dataset to excel file

# %%
df.to_excel(r'C:\Users\Anjali\Clean mental health dataset.xlsx',index= False , header= True)   #dataset exported to excel file

# %% [markdown]
# # SUMMARY TABLE FOR CLEANED DATA

# %%
df.describe()
# Out:
#              Age
# count  86.000000
# mean   34.662791
# std     8.676690
# min    -1.000000
# 25%    30.000000
# 50%    35.000000
# 75%    39.750000
# max    56.000000

# %%
df['Country'].value_counts()
# Out:
# United States    84
# Bahamas, The      1
# Israel            1
# Name: Country, dtype: int64

# %%
df.mean(axis = 0)   #column mean
# Out:
# Age               34.662791
# self_employed      0.000000
# family_history     0.581395
# treatment          0.767442
# supervisor         1.058140
# dtype: float64

# %%
df.mean(axis=1)    #row mean of datframe
# Out:
# 24      33.0
# 25      35.0
# 33      42.0
# 45      38.0
# 49      30.0
#         ...
# 1186    56.0
# 1190    44.0
# 1219    38.0
# 1221    46.0
# 1249    30.0
# Length: 86, dtype: float64

# %%
df.median()
# Out:
# Age               35.0
# self_employed      0.0
# family_history     1.0
# treatment          1.0
# supervisor         1.0
# dtype: float64

# %%
df.mode()
# Out:
#       Data and Time   Age Gender        Country state self_employed  \
# 0  27-08-2014 12:43  35.0      1  United States    CA             0
# 1  27-08-2014 15:22   NaN    NaN            NaN   NaN           NaN
#
#   family_history treatment work_interfere    no_employees  ...   anonymity  \
# 0              1         1      Sometimes          26-100  ...  Don't know
# 1            NaN       NaN            NaN  More than 1000  ...         NaN
#
#         leave mental_health_consequence phys_health_consequence     coworkers  \
# 0  Don't know                        No                      No  Some of them
# 1         NaN                       NaN                     NaN           NaN
#
#   supervisor mental_health_interview phys_health_interview mental_vs_physical  \
# 0          1                      No                 Maybe         Don't know
# 1        NaN                     NaN                   NaN                NaN
#
#   obs_consequence
# 0              No
# ...

# %%
df.std()
# Out:
# Age               8.676690
# self_employed     0.000000
# family_history    0.496224
# treatment         0.424941
# supervisor        0.725253
# dtype: float64

# %%
df.var()
# Out:
# Age               75.284952
# self_employed      0.000000
# family_history     0.246238
# treatment          0.180575
# supervisor         0.525992
# dtype: float64

# %%
df.sum(1)
# Out:
# 24      33
# 25      35
# 33      42
# 45      38
# 49      30
#         ..
# 1186    56
# 1190    44
# 1219    38
# 1221    46
# 1249    30
# Length: 86, dtype: int64

# %%
df['Age'].max()
# Out:
# 56

# %% [markdown]
# #  FINISHED
